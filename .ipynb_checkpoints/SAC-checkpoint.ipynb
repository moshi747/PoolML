# %%
from spinup.algos.pytorch.sac.sac import sac
from spinup.algos.pytorch.ppo.ppo import ppo
from spinup.algos.pytorch.ddpg.ddpg import ddpg
from spinup.algos.pytorch.td3.td3 import td3

# %%
import numpy as np
import gym
import pooltool as pt

# %%
import math

# %%
import torch
reg_net = torch.load('reg_net.pt')

# %%
n_balls = 2
labels = ['cue', '1', '2', '3', '4', '5', '6', '7', '8', '9']
table = pt.PocketTable(model_name="7_foot")
pockets = table.get_pockets()

def random_ball():
    a = np.random.rand(2)
    a[0] = (0.93)*a[0]+0.03
    a[1] = (1.92)*a[1]+0.03
    return a

def generate_balls():
    points = []
    points.append(random_ball())
    
    for _ in range(n_balls):
        close = True
        while close:
            test = random_ball()
            close = False
            for point in points:
                if np.square(point - test).sum() < 0.06:
                    close = True
                    break
        points.append(test)

    balls = {}
    
    for i in range(n_balls+1):
        balls[labels[i]] = pt.Ball(labels[i], xyz=points[i])

    return balls

def balls_to_obs(balls):
    ar = tuple(x.rvw[0,:2] for x in balls.values())
    return np.hstack(ar)


def shoot(balls, speed, vspin, hspin):

    cue = pt.Cue(cueing_ball=balls['cue'])
    cue.aim_for_best_pocket(balls['1'], pockets.values())

    cue.strike(V0=speed, b=vspin, a=hspin)
    shot = pt.System(cue=cue, table=table, balls=balls)

    try:
        shot.simulate(continuize=True)
    except:
        pass
                
    return balls

# %%
from gym import spaces
import numpy as np


class Pool(gym.Env):
    #metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 4}

    def __init__(self, render_mode=None, size=5):
        self.size = size  # The size of the square grid
        self.window_size = 512  # The size of the PyGame window

        # Observations are dictionaries with the agent's and the target's location.
        # Each location is encoded as an element of {0, ..., `size`}^2, i.e. MultiDiscrete([size, size]).
        self.observation_space = spaces.Box(low=np.tile(np.array([0.03],dtype=np.float32),n_balls*2+2),
                                            high=np.tile(np.array([0.96, 1.95],dtype=np.float32), n_balls+1),
                                            dtype=np.float32)

        # 3 dimensions corresponding to speed, vspin, hspin
        self.action_space = spaces.Box(low=np.array([-1, -1, -1],dtype=np.float32),
                                       high=np.array([1, 1, 1],dtype=np.float32), dtype=np.float32)


        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
    
    
    def reset(self, seed=None, options=None):
            
        # Generate stargint layout of balls
        balls = generate_balls()
        self.balls = balls

        observation = balls_to_obs(balls)

        return observation
    
    def step(self, action):
        
        balls = self.balls
        
        action = action*np.array([3,0.4,0.3])+np.array([3,0,0])
                
        balls = shoot(balls, action[0], action[1], action[2])
        
        on_table = [key for key, value in balls.items() if value.rvw[0,2] > 0]
        
        if 'cue' not in on_table:
            reward = -4
        elif '1' in on_table:
            reward = 0
        elif '2' in on_table:
            pred = reg_net(torch.as_tensor(np.hstack((balls['cue'].rvw[0,:2],
                                                      balls['2'].rvw[0,:2])), dtype=torch.float32))
            reward = math.exp(pred.item()*n_balls)
        else:
            reward = 0
        
        terminated = True

        observation = balls_to_obs(balls)
        
        return observation, reward, terminated, False

# %%
td3(Pool)
# Out:
# Logging data to /tmp/experiments/1677945030/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{},
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"Pool",
#     "epochs":	100,
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x2c89f2ec0>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1677945030",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1677945030/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "max_ep_len":	1000,
#     "noise_clip":	0.5,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 68355, 	 q1: 68609, 	 q2: 68609
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            1.41 |
# |          StdEpRet |            3.08 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.872 |
# |      StdTestEpRet |             3.1 |
# |      MaxTestEpRet |            5.92 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.35 |
# |         StdQ1Vals |            1.46 |
# |         MaxQ1Vals |             9.5 |
# |         MinQ1Vals |           -5.49 |
# |     AverageQ2Vals |            1.34 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |            10.1 |
# |         MinQ2Vals |           -6.26 |
# |            LossPi |           -3.61 |
# |             LossQ |            13.7 |
# |              Time |            24.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            1.42 |
# |          StdEpRet |            3.04 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.18 |
# |      StdTestEpRet |            2.67 |
# |      MaxTestEpRet |            7.19 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            1.42 |
# |         StdQ1Vals |            1.74 |
# |         MaxQ1Vals |            10.5 |
# |         MinQ1Vals |           -7.97 |
# |     AverageQ2Vals |            1.42 |
# |         StdQ2Vals |            1.72 |
# |         MaxQ2Vals |            10.6 |
# |         MinQ2Vals |           -7.33 |
# |            LossPi |            -4.3 |
# |             LossQ |            11.6 |
# |              Time |            50.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            1.76 |
# |          StdEpRet |            3.04 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.72 |
# |      StdTestEpRet |            1.88 |
# |      MaxTestEpRet |            7.39 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            1.46 |
# |         StdQ1Vals |            1.71 |
# |         MaxQ1Vals |            10.7 |
# |         MinQ1Vals |            -7.1 |
# |     AverageQ2Vals |            1.46 |
# |         StdQ2Vals |             1.7 |
# |         MaxQ2Vals |            13.9 |
# |         MinQ2Vals |           -7.58 |
# |            LossPi |           -3.62 |
# |             LossQ |            11.9 |
# |              Time |            76.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            1.99 |
# |          StdEpRet |            2.94 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.06 |
# |      StdTestEpRet |            3.49 |
# |      MaxTestEpRet |            6.64 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |             1.6 |
# |         StdQ1Vals |            1.71 |
# |         MaxQ1Vals |            11.8 |
# |         MinQ1Vals |           -7.77 |
# |     AverageQ2Vals |             1.6 |
# |         StdQ2Vals |             1.7 |
# |         MaxQ2Vals |            11.1 |
# |         MinQ2Vals |           -8.08 |
# |            LossPi |           -2.88 |
# |             LossQ |            11.9 |
# |              Time |             103 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            2.08 |
# |          StdEpRet |            2.84 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.59 |
# |      StdTestEpRet |            3.12 |
# |      MaxTestEpRet |            6.75 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |             1.7 |
# |         StdQ1Vals |             1.7 |
# |         MaxQ1Vals |            10.6 |
# |         MinQ1Vals |           -8.55 |
# |     AverageQ2Vals |             1.7 |
# |         StdQ2Vals |            1.68 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -9.05 |
# |            LossPi |           -2.72 |
# |             LossQ |            11.8 |
# |              Time |             128 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            2.12 |
# |          StdEpRet |            2.88 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.31 |
# |      StdTestEpRet |             1.5 |
# |      MaxTestEpRet |            5.09 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            1.78 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -8.31 |
# |     AverageQ2Vals |            1.78 |
# |         StdQ2Vals |            1.66 |
# |         MaxQ2Vals |            10.8 |
# |         MinQ2Vals |           -9.17 |
# |            LossPi |           -2.73 |
# |             LossQ |            11.8 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            1.95 |
# |          StdEpRet |            2.87 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.5 |
# |      StdTestEpRet |            1.62 |
# |      MaxTestEpRet |            4.55 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            1.81 |
# |         StdQ1Vals |            1.68 |
# |         MaxQ1Vals |            11.7 |
# |         MinQ1Vals |           -7.48 |
# |     AverageQ2Vals |            1.81 |
# |         StdQ2Vals |            1.65 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -8.91 |
# |            LossPi |            -2.7 |
# |             LossQ |            11.9 |
# |              Time |             179 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            2.11 |
# |          StdEpRet |            2.88 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.22 |
# |      StdTestEpRet |             3.9 |
# |      MaxTestEpRet |            7.29 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |            1.84 |
# |         StdQ1Vals |            1.65 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |            -8.8 |
# |     AverageQ2Vals |            1.84 |
# |         StdQ2Vals |            1.63 |
# |         MaxQ2Vals |            10.3 |
# |         MinQ2Vals |           -9.06 |
# |            LossPi |           -2.67 |
# |             LossQ |            11.9 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            2.06 |
# |          StdEpRet |            2.82 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.6 |
# |      StdTestEpRet |            2.63 |
# |      MaxTestEpRet |            5.37 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            1.87 |
# |         StdQ1Vals |            1.63 |
# |         MaxQ1Vals |            12.2 |
# |         MinQ1Vals |           -8.44 |
# |     AverageQ2Vals |            1.87 |
# |         StdQ2Vals |            1.62 |
# |         MaxQ2Vals |            11.9 |
# |         MinQ2Vals |           -8.55 |
# |            LossPi |           -2.66 |
# |             LossQ |              12 |
# |              Time |             230 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            2.08 |
# |          StdEpRet |            2.85 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.654 |
# |      StdTestEpRet |            2.71 |
# |      MaxTestEpRet |            5.31 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            1.89 |
# |         StdQ1Vals |            1.62 |
# |         MaxQ1Vals |            10.5 |
# |         MinQ1Vals |            -8.4 |
# |     AverageQ2Vals |            1.89 |
# |         StdQ2Vals |             1.6 |
# |         MaxQ2Vals |            11.6 |
# |         MinQ2Vals |           -13.2 |
# |            LossPi |           -2.64 |
# |             LossQ |              12 |
# |              Time |             255 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            2.07 |
# |          StdEpRet |            2.82 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.13 |
# |      StdTestEpRet |            3.09 |
# |      MaxTestEpRet |            7.08 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            1.91 |
# |         StdQ1Vals |            1.62 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -9.34 |
# |     AverageQ2Vals |            1.91 |
# |         StdQ2Vals |            1.59 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -11.2 |
# |            LossPi |           -2.67 |
# |             LossQ |              12 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            2.03 |
# |          StdEpRet |            2.78 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.22 |
# |      StdTestEpRet |            3.93 |
# |      MaxTestEpRet |            7.31 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            1.91 |
# |         StdQ1Vals |            1.61 |
# |         MaxQ1Vals |            12.4 |
# |         MinQ1Vals |           -8.68 |
# |     AverageQ2Vals |            1.91 |
# |         StdQ2Vals |            1.57 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |           -9.54 |
# |            LossPi |           -2.66 |
# |             LossQ |              12 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            2.07 |
# |          StdEpRet |            2.74 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.04 |
# |      StdTestEpRet |               3 |
# |      MaxTestEpRet |            5.17 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |            1.93 |
# |         StdQ1Vals |            1.59 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.91 |
# |     AverageQ2Vals |            1.93 |
# |         StdQ2Vals |            1.55 |
# |         MaxQ2Vals |            10.8 |
# |         MinQ2Vals |           -8.59 |
# |            LossPi |           -2.68 |
# |             LossQ |              12 |
# |              Time |             330 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            2.06 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.51 |
# |      StdTestEpRet |            1.63 |
# |      MaxTestEpRet |             5.3 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |            1.94 |
# |         StdQ1Vals |            1.57 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -8.73 |
# |     AverageQ2Vals |            1.94 |
# |         StdQ2Vals |            1.54 |
# |         MaxQ2Vals |            10.9 |
# |         MinQ2Vals |           -10.3 |
# |            LossPi |           -2.69 |
# |             LossQ |              12 |
# |              Time |             355 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            2.19 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.73 |
# |      StdTestEpRet |            1.85 |
# |      MaxTestEpRet |            5.14 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            1.96 |
# |         StdQ1Vals |            1.57 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -8.68 |
# |     AverageQ2Vals |            1.96 |
# |         StdQ2Vals |            1.54 |
# |         MaxQ2Vals |            12.2 |
# |         MinQ2Vals |           -7.89 |
# |            LossPi |            -2.7 |
# |             LossQ |              12 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            2.12 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.904 |
# |      StdTestEpRet |            3.91 |
# |      MaxTestEpRet |               7 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |            1.96 |
# |         StdQ1Vals |            1.56 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -9.49 |
# |     AverageQ2Vals |            1.96 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |            12.3 |
# |         MinQ2Vals |           -8.63 |
# |            LossPi |           -2.68 |
# |             LossQ |            11.9 |
# |              Time |             405 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            2.09 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.54 |
# |      StdTestEpRet |            2.35 |
# |      MaxTestEpRet |            7.02 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |            1.97 |
# |         StdQ1Vals |            1.55 |
# |         MaxQ1Vals |            11.7 |
# |         MinQ1Vals |              -9 |
# |     AverageQ2Vals |            1.97 |
# |         StdQ2Vals |            1.52 |
# |         MaxQ2Vals |            11.9 |
# |         MinQ2Vals |           -8.73 |
# |            LossPi |           -2.68 |
# |             LossQ |            11.9 |
# |              Time |             431 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            2.06 |
# |          StdEpRet |            2.81 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.65 |
# |      StdTestEpRet |            2.23 |
# |      MaxTestEpRet |             7.2 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            1.98 |
# |         StdQ1Vals |            1.55 |
# |         MaxQ1Vals |            11.3 |
# |         MinQ1Vals |           -8.85 |
# |     AverageQ2Vals |            1.98 |
# |         StdQ2Vals |            1.52 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |            -9.2 |
# |            LossPi |           -2.67 |
# |             LossQ |            11.9 |
# |              Time |             456 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            2.18 |
# |          StdEpRet |            2.78 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             3.4 |
# |      StdTestEpRet |            1.86 |
# |      MaxTestEpRet |            5.57 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |               2 |
# |         StdQ1Vals |            1.53 |
# |         MaxQ1Vals |            11.8 |
# |         MinQ1Vals |           -7.98 |
# |     AverageQ2Vals |               2 |
# |         StdQ2Vals |             1.5 |
# |         MaxQ2Vals |            12.2 |
# |         MinQ2Vals |           -10.8 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.9 |
# |              Time |             481 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             2.1 |
# |          StdEpRet |            2.82 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.87 |
# |      StdTestEpRet |            3.27 |
# |      MaxTestEpRet |            7.06 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |               2 |
# |         StdQ1Vals |            1.54 |
# |         MaxQ1Vals |            11.8 |
# |         MinQ1Vals |           -9.15 |
# |     AverageQ2Vals |               2 |
# |         StdQ2Vals |            1.51 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -9.58 |
# |            LossPi |           -2.67 |
# |             LossQ |            11.9 |
# |              Time |             505 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            2.04 |
# |          StdEpRet |            2.77 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.77 |
# |      StdTestEpRet |            2.67 |
# |      MaxTestEpRet |            7.26 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |            1.99 |
# |         StdQ1Vals |            1.52 |
# |         MaxQ1Vals |            12.4 |
# |         MinQ1Vals |           -11.9 |
# |     AverageQ2Vals |            1.99 |
# |         StdQ2Vals |             1.5 |
# |         MaxQ2Vals |            12.1 |
# |         MinQ2Vals |           -10.7 |
# |            LossPi |           -2.66 |
# |             LossQ |              12 |
# |              Time |             531 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            2.07 |
# |          StdEpRet |            2.83 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.13 |
# |      StdTestEpRet |            2.12 |
# |      MaxTestEpRet |            4.48 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |               2 |
# |         StdQ1Vals |            1.51 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -10.4 |
# |     AverageQ2Vals |               2 |
# |         StdQ2Vals |            1.49 |
# |         MaxQ2Vals |            11.4 |
# |         MinQ2Vals |           -9.33 |
# |            LossPi |           -2.66 |
# |             LossQ |              12 |
# |              Time |             556 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            2.17 |
# |          StdEpRet |            2.75 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.91 |
# |      StdTestEpRet |            2.23 |
# |      MaxTestEpRet |            7.25 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |            2.01 |
# |         StdQ1Vals |            1.51 |
# |         MaxQ1Vals |              11 |
# |         MinQ1Vals |           -9.07 |
# |     AverageQ2Vals |            2.01 |
# |         StdQ2Vals |            1.49 |
# |         MaxQ2Vals |            11.9 |
# |         MinQ2Vals |           -9.64 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.9 |
# |              Time |             580 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            2.08 |
# |          StdEpRet |             2.8 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.75 |
# |      StdTestEpRet |            3.04 |
# |      MaxTestEpRet |            7.33 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            2.01 |
# |         StdQ1Vals |             1.5 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -9.21 |
# |     AverageQ2Vals |            2.01 |
# |         StdQ2Vals |            1.49 |
# |         MaxQ2Vals |            11.5 |
# |         MinQ2Vals |           -8.33 |
# |            LossPi |           -2.65 |
# |             LossQ |              12 |
# |              Time |             605 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            2.13 |
# |          StdEpRet |            2.72 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.39 |
# |      StdTestEpRet |            1.98 |
# |      MaxTestEpRet |            6.87 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |            2.01 |
# |         StdQ1Vals |            1.49 |
# |         MaxQ1Vals |            12.9 |
# |         MinQ1Vals |           -9.64 |
# |     AverageQ2Vals |            2.01 |
# |         StdQ2Vals |            1.48 |
# |         MaxQ2Vals |            12.6 |
# |         MinQ2Vals |           -9.92 |
# |            LossPi |           -2.63 |
# |             LossQ |            11.9 |
# |              Time |             630 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            2.14 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.32 |
# |      StdTestEpRet |            2.88 |
# |      MaxTestEpRet |            7.37 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |            2.02 |
# |         StdQ1Vals |            1.49 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -9.32 |
# |     AverageQ2Vals |            2.02 |
# |         StdQ2Vals |            1.48 |
# |         MaxQ2Vals |            13.8 |
# |         MinQ2Vals |           -9.92 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.9 |
# |              Time |             656 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            2.14 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.02 |
# |      StdTestEpRet |            2.19 |
# |      MaxTestEpRet |            4.47 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.48 |
# |         MaxQ1Vals |            11.4 |
# |         MinQ1Vals |           -9.31 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |            12.3 |
# |         MinQ2Vals |           -11.4 |
# |            LossPi |           -2.67 |
# |             LossQ |            11.8 |
# |              Time |             680 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            2.14 |
# |          StdEpRet |            2.71 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.05 |
# |      StdTestEpRet |            2.34 |
# |      MaxTestEpRet |            7.07 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |            2.03 |
# |         StdQ1Vals |            1.49 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -9.11 |
# |     AverageQ2Vals |            2.03 |
# |         StdQ2Vals |            1.48 |
# |         MaxQ2Vals |            10.6 |
# |         MinQ2Vals |           -11.6 |
# |            LossPi |           -2.68 |
# |             LossQ |            11.9 |
# |              Time |             705 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            2.06 |
# |          StdEpRet |            2.72 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.07 |
# |      StdTestEpRet |            1.17 |
# |      MaxTestEpRet |            4.07 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |            2.03 |
# |         StdQ1Vals |            1.48 |
# |         MaxQ1Vals |            11.6 |
# |         MinQ1Vals |             -10 |
# |     AverageQ2Vals |            2.03 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |            13.4 |
# |         MinQ2Vals |           -10.8 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.9 |
# |              Time |             729 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            2.12 |
# |          StdEpRet |            2.75 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.19 |
# |      StdTestEpRet |            1.98 |
# |      MaxTestEpRet |            3.55 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |            2.03 |
# |         StdQ1Vals |            1.47 |
# |         MaxQ1Vals |            13.2 |
# |         MinQ1Vals |           -10.1 |
# |     AverageQ2Vals |            2.03 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |              13 |
# |         MinQ2Vals |           -9.55 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.8 |
# |              Time |             754 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            2.17 |
# |          StdEpRet |            2.74 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             2.4 |
# |      StdTestEpRet |            1.85 |
# |      MaxTestEpRet |            5.91 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.47 |
# |         MaxQ1Vals |            11.6 |
# |         MinQ1Vals |           -10.7 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |           -10.9 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.8 |
# |              Time |             779 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            2.11 |
# |          StdEpRet |            2.69 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.4 |
# |      StdTestEpRet |            3.98 |
# |      MaxTestEpRet |            7.16 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.47 |
# |         MaxQ1Vals |            12.2 |
# |         MinQ1Vals |           -9.71 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |            12.6 |
# |         MinQ2Vals |           -8.86 |
# |            LossPi |           -2.67 |
# |             LossQ |            11.7 |
# |              Time |             804 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            2.05 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.37 |
# |      StdTestEpRet |            1.52 |
# |      MaxTestEpRet |             5.6 |
# |      MinTestEpRet |            1.36 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.32e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.47 |
# |         MaxQ1Vals |            11.9 |
# |         MinQ1Vals |           -9.05 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -9.71 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.8 |
# |              Time |             828 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            2.11 |
# |          StdEpRet |            2.68 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.94 |
# |      StdTestEpRet |            2.25 |
# |      MaxTestEpRet |            4.83 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.36e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            10.8 |
# |         MinQ1Vals |           -8.51 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |             -13 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.8 |
# |              Time |             853 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            2.11 |
# |          StdEpRet |             2.7 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.31 |
# |      StdTestEpRet |            1.52 |
# |      MaxTestEpRet |            4.48 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.4e+05 |
# |     AverageQ1Vals |            2.05 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            13.8 |
# |         MinQ1Vals |           -8.62 |
# |     AverageQ2Vals |            2.05 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |           -9.01 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.7 |
# |              Time |             878 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            2.13 |
# |          StdEpRet |            2.68 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.48 |
# |      StdTestEpRet |            2.48 |
# |      MaxTestEpRet |            7.36 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.44e+05 |
# |     AverageQ1Vals |            2.05 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            12.3 |
# |         MinQ1Vals |           -8.97 |
# |     AverageQ2Vals |            2.05 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            11.2 |
# |         MinQ2Vals |           -10.1 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.8 |
# |              Time |             903 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            2.19 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.07 |
# |      StdTestEpRet |            2.73 |
# |      MaxTestEpRet |            6.16 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.48e+05 |
# |     AverageQ1Vals |            2.05 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            11.7 |
# |         MinQ1Vals |           -12.3 |
# |     AverageQ2Vals |            2.05 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |           -11.6 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.6 |
# |              Time |             927 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            2.16 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.421 |
# |      StdTestEpRet |            3.94 |
# |      MaxTestEpRet |            6.76 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.52e+05 |
# |     AverageQ1Vals |            2.05 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            12.3 |
# |         MinQ1Vals |           -9.95 |
# |     AverageQ2Vals |            2.05 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            12.7 |
# |         MinQ2Vals |           -10.2 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.7 |
# |              Time |             951 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            2.15 |
# |          StdEpRet |            2.74 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.01 |
# |      StdTestEpRet |            1.58 |
# |      MaxTestEpRet |            4.83 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.56e+05 |
# |     AverageQ1Vals |            2.04 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -9.51 |
# |     AverageQ2Vals |            2.04 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            12.1 |
# |         MinQ2Vals |           -10.9 |
# |            LossPi |           -2.63 |
# |             LossQ |            11.7 |
# |              Time |             976 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            2.17 |
# |          StdEpRet |            2.71 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.09 |
# |      StdTestEpRet |             1.9 |
# |      MaxTestEpRet |            7.35 |
# |      MinTestEpRet |               1 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.6e+05 |
# |     AverageQ1Vals |            2.06 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            11.7 |
# |         MinQ1Vals |           -8.13 |
# |     AverageQ2Vals |            2.06 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -9.02 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.7 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            2.17 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.13 |
# |      StdTestEpRet |            1.93 |
# |      MaxTestEpRet |            5.78 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.64e+05 |
# |     AverageQ1Vals |            2.07 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            11.3 |
# |         MinQ1Vals |           -8.78 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -8.54 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.6 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            2.21 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.78 |
# |      StdTestEpRet |            2.08 |
# |      MaxTestEpRet |            7.19 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.68e+05 |
# |     AverageQ1Vals |            2.06 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            12.5 |
# |         MinQ1Vals |           -9.37 |
# |     AverageQ2Vals |            2.06 |
# |         StdQ2Vals |            1.46 |
# |         MaxQ2Vals |            12.9 |
# |         MinQ2Vals |            -9.4 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.6 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            2.08 |
# |          StdEpRet |            2.67 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             2.4 |
# |      StdTestEpRet |            3.84 |
# |      MaxTestEpRet |            7.32 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.72e+05 |
# |     AverageQ1Vals |            2.07 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |              12 |
# |         MinQ1Vals |           -9.85 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -11.5 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.6 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            2.15 |
# |          StdEpRet |            2.72 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.89 |
# |      StdTestEpRet |            2.43 |
# |      MaxTestEpRet |            5.59 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.76e+05 |
# |     AverageQ1Vals |            2.07 |
# |         StdQ1Vals |            1.45 |
# |         MaxQ1Vals |            11.9 |
# |         MinQ1Vals |           -10.3 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -9.11 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.6 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            2.22 |
# |          StdEpRet |             2.7 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.78 |
# |      StdTestEpRet |            2.88 |
# |      MaxTestEpRet |            7.35 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.8e+05 |
# |     AverageQ1Vals |            2.07 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            10.6 |
# |         MinQ1Vals |           -10.4 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            11.1 |
# |         MinQ2Vals |           -8.62 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.5 |
# |              Time |        1.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            2.12 |
# |          StdEpRet |            2.79 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.7 |
# |      StdTestEpRet |            1.96 |
# |      MaxTestEpRet |            6.72 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.84e+05 |
# |     AverageQ1Vals |            2.07 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            12.1 |
# |         MinQ1Vals |           -9.09 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -9.01 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.6 |
# |              Time |        1.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            2.12 |
# |          StdEpRet |            2.71 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.91 |
# |      StdTestEpRet |            2.56 |
# |      MaxTestEpRet |            5.84 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.88e+05 |
# |     AverageQ1Vals |            2.06 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            13.4 |
# |         MinQ1Vals |           -7.95 |
# |     AverageQ2Vals |            2.07 |
# |         StdQ2Vals |            1.44 |
# ...
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            2.23 |
# |          StdEpRet |            2.77 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.37 |
# |      StdTestEpRet |            2.25 |
# |      MaxTestEpRet |            4.62 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.4e+05 |
# |     AverageQ1Vals |            2.12 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |              11 |
# |         MinQ1Vals |           -9.62 |
# |     AverageQ2Vals |            2.12 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |              13 |
# |         MinQ2Vals |           -10.7 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            2.19 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.69 |
# |      StdTestEpRet |            2.94 |
# |      MaxTestEpRet |            7.35 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.44e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            10.3 |
# |         MinQ1Vals |           -9.65 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.1 |
# |         MinQ2Vals |           -8.25 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            2.18 |
# |          StdEpRet |            2.82 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.2 |
# |      StdTestEpRet |            3.09 |
# |      MaxTestEpRet |            5.67 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.48e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -7.74 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            10.4 |
# |         MinQ2Vals |           -9.26 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.3 |
# |              Time |        2.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            2.16 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.83 |
# |      StdTestEpRet |             3.1 |
# |      MaxTestEpRet |             7.3 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.52e+05 |
# |     AverageQ1Vals |            2.12 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -9.46 |
# |     AverageQ2Vals |            2.12 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            13.2 |
# |         MinQ2Vals |           -8.89 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            2.09 |
# |          StdEpRet |            2.81 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.74 |
# |      StdTestEpRet |            3.18 |
# |      MaxTestEpRet |            7.38 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.56e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            13.5 |
# |         MinQ1Vals |           -10.1 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.9 |
# |         MinQ2Vals |           -8.73 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.3 |
# |              Time |        2.21e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |             2.2 |
# |          StdEpRet |            2.79 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.58 |
# |      StdTestEpRet |            2.32 |
# |      MaxTestEpRet |            7.29 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.6e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            11.8 |
# |         MinQ1Vals |           -8.84 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -9.19 |
# |            LossPi |           -2.63 |
# |             LossQ |            11.3 |
# |              Time |        2.24e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            2.06 |
# |          StdEpRet |             2.7 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.86 |
# |      StdTestEpRet |            2.83 |
# |      MaxTestEpRet |            6.46 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.64e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |              11 |
# |         MinQ1Vals |           -12.2 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -9.16 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.3 |
# |              Time |        2.26e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            2.16 |
# |          StdEpRet |            2.81 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.52 |
# |      StdTestEpRet |            2.44 |
# |      MaxTestEpRet |            7.36 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.68e+05 |
# |     AverageQ1Vals |            2.12 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            11.3 |
# |         MinQ1Vals |           -7.53 |
# |     AverageQ2Vals |            2.12 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.1 |
# |         MinQ2Vals |           -10.1 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.4 |
# |              Time |        2.29e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            2.22 |
# |          StdEpRet |            2.73 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.93 |
# |      StdTestEpRet |             3.1 |
# |      MaxTestEpRet |            7.34 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.72e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |              13 |
# |         MinQ1Vals |           -8.92 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            13.4 |
# |         MinQ2Vals |           -10.4 |
# |            LossPi |           -2.64 |
# |             LossQ |            11.4 |
# |              Time |        2.31e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            2.18 |
# |          StdEpRet |            2.76 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.95 |
# |      StdTestEpRet |            2.82 |
# |      MaxTestEpRet |            6.89 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.76e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -9.12 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            12.2 |
# |         MinQ2Vals |           -8.59 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.4 |
# |              Time |        2.34e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            2.16 |
# |          StdEpRet |            2.82 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.81 |
# |      StdTestEpRet |            4.17 |
# |      MaxTestEpRet |            7.38 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.8e+05 |
# |     AverageQ1Vals |            2.11 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            11.4 |
# |         MinQ1Vals |           -8.32 |
# |     AverageQ2Vals |            2.11 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.5 |
# |         MinQ2Vals |           -12.4 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.4 |
# |              Time |        2.36e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            2.26 |
# |          StdEpRet |            2.77 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.17 |
# |      StdTestEpRet |            2.98 |
# |      MaxTestEpRet |            6.75 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.84e+05 |
# |     AverageQ1Vals |            2.13 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            10.7 |
# |         MinQ1Vals |           -9.93 |
# |     AverageQ2Vals |            2.13 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |              14 |
# |         MinQ2Vals |           -8.23 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.39e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            2.23 |
# |          StdEpRet |            2.88 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            5.36 |
# |      StdTestEpRet |            2.16 |
# |      MaxTestEpRet |            7.28 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.88e+05 |
# |     AverageQ1Vals |            2.12 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            10.6 |
# |         MinQ1Vals |            -7.6 |
# |     AverageQ2Vals |            2.12 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |           -9.39 |
# |            LossPi |           -2.65 |
# |             LossQ |            11.3 |
# |              Time |        2.41e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            2.24 |
# |          StdEpRet |            2.85 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.13 |
# |      StdTestEpRet |            2.93 |
# |      MaxTestEpRet |            7.32 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.92e+05 |
# |     AverageQ1Vals |            2.13 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            10.3 |
# |         MinQ1Vals |           -8.55 |
# |     AverageQ2Vals |            2.13 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |           -9.45 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.44e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            2.16 |
# |          StdEpRet |            2.79 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.18 |
# |      StdTestEpRet |            2.86 |
# |      MaxTestEpRet |            5.98 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        3.96e+05 |
# |     AverageQ1Vals |            2.12 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            11.4 |
# |         MinQ1Vals |           -7.59 |
# |     AverageQ2Vals |            2.12 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            13.8 |
# |         MinQ2Vals |           -8.74 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.3 |
# |              Time |        2.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            2.22 |
# |          StdEpRet |            2.79 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.93 |
# |      StdTestEpRet |            1.78 |
# |      MaxTestEpRet |            5.82 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           4e+05 |
# |     AverageQ1Vals |            2.13 |
# |         StdQ1Vals |            1.44 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |            -8.6 |
# |     AverageQ2Vals |            2.13 |
# |         StdQ2Vals |            1.45 |
# |         MaxQ2Vals |            11.1 |
# |         MinQ2Vals |            -8.4 |
# |            LossPi |           -2.66 |
# |             LossQ |            11.4 |
# |              Time |        2.49e+03 |
# ---------------------------------------

# %%
6

# %%
sac(Pool, epochs = 100, alpha = 0)
# Out:
# Logging data to /tmp/experiments/1678142861/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{},
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0,
#     "batch_size":	100,
#     "env_fn":	"Pool",
#     "epochs":	100,
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x2c8b0ae90>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1678142861",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1678142861/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	10,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	4000,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 69126, 	 q1: 68609, 	 q2: 68609
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |             1.6 |
# |          StdEpRet |               3 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.466 |
# |      StdTestEpRet |            3.09 |
# |      MaxTestEpRet |            4.62 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           4e+03 |
# |     AverageQ1Vals |            1.61 |
# |         StdQ1Vals |            1.33 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -4.25 |
# |     AverageQ2Vals |            1.61 |
# |         StdQ2Vals |            1.24 |
# |         MaxQ2Vals |            10.5 |
# |         MinQ2Vals |           -5.12 |
# |      AverageLogPi |             314 |
# |          StdLogPi |             113 |
# |          MaxLogPi |             624 |
# |          MinLogPi |           -7.79 |
# |            LossPi |           -2.36 |
# |             LossQ |            13.8 |
# |              Time |            27.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            1.46 |
# |          StdEpRet |            3.07 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            3.09 |
# |      StdTestEpRet |            2.43 |
# |      MaxTestEpRet |            7.29 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           8e+03 |
# |     AverageQ1Vals |            1.58 |
# |         StdQ1Vals |            1.62 |
# |         MaxQ1Vals |            10.7 |
# |         MinQ1Vals |           -6.51 |
# |     AverageQ2Vals |            1.58 |
# |         StdQ2Vals |            1.54 |
# |         MaxQ2Vals |            9.62 |
# |         MinQ2Vals |           -5.99 |
# |      AverageLogPi |             395 |
# |          StdLogPi |            63.9 |
# |          MaxLogPi |             631 |
# |          MinLogPi |             152 |
# |            LossPi |           -1.09 |
# |             LossQ |            12.3 |
# |              Time |            58.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            1.18 |
# |          StdEpRet |            3.28 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.852 |
# |      StdTestEpRet |            3.74 |
# |      MaxTestEpRet |            7.35 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.2e+04 |
# |     AverageQ1Vals |            1.51 |
# |         StdQ1Vals |            1.63 |
# |         MaxQ1Vals |            10.3 |
# |         MinQ1Vals |           -7.48 |
# |     AverageQ2Vals |            1.51 |
# |         StdQ2Vals |            1.58 |
# |         MaxQ2Vals |            10.5 |
# |         MinQ2Vals |           -5.91 |
# |      AverageLogPi |             396 |
# |          StdLogPi |            63.9 |
# |          MaxLogPi |             651 |
# |          MinLogPi |             155 |
# |            LossPi |          -0.785 |
# |             LossQ |            12.9 |
# |              Time |            91.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |           0.929 |
# |          StdEpRet |            3.42 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.128 |
# |      StdTestEpRet |            3.56 |
# |      MaxTestEpRet |            5.69 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.6e+04 |
# |     AverageQ1Vals |            1.36 |
# |         StdQ1Vals |            1.61 |
# |         MaxQ1Vals |            12.3 |
# |         MinQ1Vals |           -6.95 |
# |     AverageQ2Vals |            1.36 |
# |         StdQ2Vals |            1.56 |
# |         MaxQ2Vals |            10.4 |
# |         MinQ2Vals |           -6.49 |
# |      AverageLogPi |             396 |
# |          StdLogPi |            64.2 |
# |          MaxLogPi |             632 |
# |          MinLogPi |             147 |
# |            LossPi |          -0.578 |
# |             LossQ |            14.4 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            0.97 |
# |          StdEpRet |            3.44 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.726 |
# |      StdTestEpRet |            2.58 |
# |      MaxTestEpRet |            3.97 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           2e+04 |
# |     AverageQ1Vals |            1.27 |
# |         StdQ1Vals |            1.56 |
# |         MaxQ1Vals |            11.3 |
# |         MinQ1Vals |           -7.08 |
# |     AverageQ2Vals |            1.27 |
# |         StdQ2Vals |            1.52 |
# |         MaxQ2Vals |            10.2 |
# |         MinQ2Vals |           -7.27 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.3 |
# |          MaxLogPi |             656 |
# |          MinLogPi |             134 |
# |            LossPi |          -0.653 |
# |             LossQ |            15.7 |
# |              Time |             166 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           0.811 |
# |          StdEpRet |            3.51 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.757 |
# |      StdTestEpRet |            3.44 |
# |      MaxTestEpRet |             6.6 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         2.4e+04 |
# |     AverageQ1Vals |            1.19 |
# |         StdQ1Vals |            1.53 |
# |         MaxQ1Vals |            11.9 |
# |         MinQ1Vals |           -7.63 |
# |     AverageQ2Vals |            1.19 |
# |         StdQ2Vals |            1.48 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -7.68 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.2 |
# |          MaxLogPi |             636 |
# |          MinLogPi |             147 |
# |            LossPi |          -0.654 |
# |             LossQ |            16.7 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           0.886 |
# |          StdEpRet |            3.47 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.07 |
# |      StdTestEpRet |             3.7 |
# |      MaxTestEpRet |            7.27 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            1.13 |
# |         StdQ1Vals |             1.5 |
# |         MaxQ1Vals |            12.2 |
# |         MinQ1Vals |           -7.91 |
# |     AverageQ2Vals |            1.13 |
# |         StdQ2Vals |            1.44 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -8.14 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             649 |
# |          MinLogPi |             147 |
# |            LossPi |          -0.648 |
# |             LossQ |            17.5 |
# |              Time |             238 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           0.901 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.95 |
# |      StdTestEpRet |            3.06 |
# |      MaxTestEpRet |            7.39 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.2e+04 |
# |     AverageQ1Vals |             1.1 |
# |         StdQ1Vals |            1.46 |
# |         MaxQ1Vals |            12.3 |
# |         MinQ1Vals |           -8.48 |
# |     AverageQ2Vals |             1.1 |
# |         StdQ2Vals |            1.42 |
# |         MaxQ2Vals |            10.2 |
# |         MinQ2Vals |           -8.12 |
# |      AverageLogPi |             397 |
# |          StdLogPi |              64 |
# |          MaxLogPi |             630 |
# |          MinLogPi |             129 |
# |            LossPi |          -0.641 |
# |             LossQ |            18.2 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            0.86 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.283 |
# |      StdTestEpRet |            4.17 |
# |      MaxTestEpRet |            7.24 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         3.6e+04 |
# |     AverageQ1Vals |            1.08 |
# |         StdQ1Vals |            1.43 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -8.72 |
# |     AverageQ2Vals |            1.08 |
# |         StdQ2Vals |            1.38 |
# |         MaxQ2Vals |            10.7 |
# |         MinQ2Vals |           -8.34 |
# |      AverageLogPi |             397 |
# |          StdLogPi |              64 |
# |          MaxLogPi |             630 |
# |          MinLogPi |             153 |
# |            LossPi |          -0.654 |
# |             LossQ |            18.5 |
# |              Time |             310 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           0.852 |
# |          StdEpRet |            3.51 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.77 |
# |      StdTestEpRet |             1.9 |
# |      MaxTestEpRet |            6.81 |
# |      MinTestEpRet |               0 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           4e+04 |
# |     AverageQ1Vals |            1.06 |
# |         StdQ1Vals |             1.4 |
# |         MaxQ1Vals |              11 |
# |         MinQ1Vals |           -8.68 |
# |     AverageQ2Vals |            1.06 |
# |         StdQ2Vals |            1.34 |
# |         MaxQ2Vals |            10.7 |
# |         MinQ2Vals |           -8.76 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             631 |
# |          MinLogPi |             130 |
# |            LossPi |          -0.671 |
# |             LossQ |              19 |
# |              Time |             347 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           0.907 |
# |          StdEpRet |            3.41 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.367 |
# |      StdTestEpRet |            3.98 |
# |      MaxTestEpRet |            7.34 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         4.4e+04 |
# |     AverageQ1Vals |            1.04 |
# |         StdQ1Vals |            1.38 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.54 |
# |     AverageQ2Vals |            1.04 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |            10.9 |
# |         MinQ2Vals |           -7.92 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.2 |
# |          MaxLogPi |             636 |
# |          MinLogPi |             148 |
# |            LossPi |          -0.656 |
# |             LossQ |            19.2 |
# |              Time |             382 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           0.823 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            2.21 |
# |      StdTestEpRet |            3.03 |
# |      MaxTestEpRet |            7.34 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         4.8e+04 |
# |     AverageQ1Vals |            1.03 |
# |         StdQ1Vals |            1.35 |
# |         MaxQ1Vals |            10.3 |
# |         MinQ1Vals |           -8.27 |
# |     AverageQ2Vals |            1.03 |
# |         StdQ2Vals |             1.3 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |           -8.18 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             642 |
# |          MinLogPi |             149 |
# |            LossPi |          -0.656 |
# |             LossQ |            19.4 |
# |              Time |             418 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           0.868 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |          -0.837 |
# |      StdTestEpRet |            3.26 |
# |      MaxTestEpRet |             4.3 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         5.2e+04 |
# |     AverageQ1Vals |           0.996 |
# |         StdQ1Vals |            1.34 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.45 |
# |     AverageQ2Vals |           0.996 |
# |         StdQ2Vals |            1.29 |
# |         MaxQ2Vals |            10.3 |
# |         MinQ2Vals |           -8.72 |
# |      AverageLogPi |             397 |
# |          StdLogPi |              64 |
# |          MaxLogPi |             634 |
# |          MinLogPi |             149 |
# |            LossPi |          -0.638 |
# |             LossQ |            19.6 |
# |              Time |             453 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           0.961 |
# |          StdEpRet |            3.41 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.247 |
# |      StdTestEpRet |            3.97 |
# |      MaxTestEpRet |            7.24 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         5.6e+04 |
# |     AverageQ1Vals |           0.997 |
# |         StdQ1Vals |            1.32 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.42 |
# |     AverageQ2Vals |           0.996 |
# |         StdQ2Vals |            1.27 |
# |         MaxQ2Vals |            13.8 |
# |         MinQ2Vals |           -8.01 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             637 |
# |          MinLogPi |             122 |
# |            LossPi |          -0.649 |
# |             LossQ |            19.8 |
# |              Time |             489 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           0.923 |
# |          StdEpRet |            3.48 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.07 |
# |      StdTestEpRet |            1.84 |
# |      MaxTestEpRet |            3.09 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           6e+04 |
# |     AverageQ1Vals |            1.01 |
# |         StdQ1Vals |             1.3 |
# |         MaxQ1Vals |            10.8 |
# |         MinQ1Vals |           -8.66 |
# |     AverageQ2Vals |            1.01 |
# |         StdQ2Vals |            1.25 |
# |         MaxQ2Vals |            10.7 |
# |         MinQ2Vals |           -8.73 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.2 |
# |          MaxLogPi |             652 |
# |          MinLogPi |             152 |
# |            LossPi |          -0.666 |
# |             LossQ |            19.9 |
# |              Time |             525 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           0.967 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.67 |
# |      StdTestEpRet |            2.77 |
# |      MaxTestEpRet |            6.22 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         6.4e+04 |
# |     AverageQ1Vals |           0.982 |
# |         StdQ1Vals |            1.29 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |              -8 |
# |     AverageQ2Vals |           0.982 |
# |         StdQ2Vals |            1.24 |
# |         MaxQ2Vals |              12 |
# |         MinQ2Vals |           -7.66 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             642 |
# |          MinLogPi |             156 |
# |            LossPi |          -0.646 |
# |             LossQ |              20 |
# |              Time |             560 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           0.846 |
# |          StdEpRet |            3.47 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |             1.3 |
# |      StdTestEpRet |            3.74 |
# |      MaxTestEpRet |            5.85 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         6.8e+04 |
# |     AverageQ1Vals |           0.988 |
# |         StdQ1Vals |            1.28 |
# |         MaxQ1Vals |            11.6 |
# |         MinQ1Vals |           -8.58 |
# |     AverageQ2Vals |           0.988 |
# |         StdQ2Vals |            1.23 |
# |         MaxQ2Vals |            10.3 |
# |         MinQ2Vals |           -9.18 |
# |      AverageLogPi |             397 |
# |          StdLogPi |              64 |
# |          MaxLogPi |             640 |
# |          MinLogPi |             149 |
# |            LossPi |          -0.664 |
# |             LossQ |            20.2 |
# |              Time |             595 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |           0.903 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.88 |
# |      StdTestEpRet |            3.35 |
# |      MaxTestEpRet |            7.06 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         7.2e+04 |
# |     AverageQ1Vals |            0.98 |
# |         StdQ1Vals |            1.27 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -7.78 |
# |     AverageQ2Vals |            0.98 |
# |         StdQ2Vals |            1.22 |
# |         MaxQ2Vals |            11.7 |
# |         MinQ2Vals |           -7.61 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             646 |
# |          MinLogPi |             135 |
# |            LossPi |          -0.658 |
# |             LossQ |            20.3 |
# |              Time |             630 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |           0.935 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           -0.23 |
# |      StdTestEpRet |             2.6 |
# |      MaxTestEpRet |            2.46 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         7.6e+04 |
# |     AverageQ1Vals |           0.983 |
# |         StdQ1Vals |            1.26 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -9.78 |
# |     AverageQ2Vals |           0.982 |
# |         StdQ2Vals |            1.21 |
# |         MaxQ2Vals |            11.5 |
# |         MinQ2Vals |           -7.98 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             650 |
# |          MinLogPi |             148 |
# |            LossPi |          -0.667 |
# |             LossQ |            20.4 |
# |              Time |             665 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             0.9 |
# |          StdEpRet |            3.46 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.03 |
# |      StdTestEpRet |            3.18 |
# |      MaxTestEpRet |               7 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           8e+04 |
# |     AverageQ1Vals |           0.974 |
# |         StdQ1Vals |            1.26 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -7.64 |
# |     AverageQ2Vals |           0.974 |
# |         StdQ2Vals |            1.21 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -8.66 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            64.1 |
# |          MaxLogPi |             627 |
# |          MinLogPi |             138 |
# |            LossPi |          -0.661 |
# |             LossQ |            20.5 |
# |              Time |             700 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           0.894 |
# |          StdEpRet |            3.46 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |         -0.0179 |
# |      StdTestEpRet |            2.91 |
# |      MaxTestEpRet |            4.86 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         8.4e+04 |
# |     AverageQ1Vals |           0.975 |
# |         StdQ1Vals |            1.25 |
# |         MaxQ1Vals |            12.1 |
# |         MinQ1Vals |           -8.56 |
# |     AverageQ2Vals |           0.975 |
# |         StdQ2Vals |             1.2 |
# |         MaxQ2Vals |            11.3 |
# |         MinQ2Vals |           -7.55 |
# |      AverageLogPi |             397 |
# |          StdLogPi |              64 |
# |          MaxLogPi |             625 |
# |          MinLogPi |             154 |
# |            LossPi |          -0.667 |
# |             LossQ |            20.5 |
# |              Time |             736 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           0.908 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           -1.21 |
# |      StdTestEpRet |            3.67 |
# |      MaxTestEpRet |            5.23 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         8.8e+04 |
# |     AverageQ1Vals |           0.964 |
# |         StdQ1Vals |            1.23 |
# |         MaxQ1Vals |            14.1 |
# |         MinQ1Vals |           -8.15 |
# |     AverageQ2Vals |           0.964 |
# |         StdQ2Vals |            1.19 |
# |         MaxQ2Vals |            12.6 |
# |         MinQ2Vals |           -8.28 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            63.9 |
# |          MaxLogPi |             646 |
# |          MinLogPi |             135 |
# |            LossPi |          -0.661 |
# |             LossQ |            20.6 |
# |              Time |             771 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           0.847 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |          -0.377 |
# |      StdTestEpRet |            3.16 |
# |      MaxTestEpRet |            4.77 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         9.2e+04 |
# |     AverageQ1Vals |           0.971 |
# |         StdQ1Vals |            1.24 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.44 |
# |     AverageQ2Vals |           0.971 |
# |         StdQ2Vals |            1.18 |
# |         MaxQ2Vals |            12.2 |
# |         MinQ2Vals |           -9.38 |
# |      AverageLogPi |             397 |
# |          StdLogPi |            63.9 |
# |          MaxLogPi |             658 |
# |          MinLogPi |             147 |
# |            LossPi |          -0.667 |
# |             LossQ |            20.6 |
# |              Time |             807 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           0.896 |
# |          StdEpRet |            3.42 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.508 |
# |      StdTestEpRet |            1.81 |
# |      MaxTestEpRet |            3.14 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         9.6e+04 |
# |     AverageQ1Vals |            0.96 |
# |         StdQ1Vals |            1.22 |
# |         MaxQ1Vals |            11.9 |
# |         MinQ1Vals |           -7.83 |
# |     AverageQ2Vals |            0.96 |
# |         StdQ2Vals |            1.18 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -9.55 |
# |      AverageLogPi |             431 |
# |          StdLogPi |              72 |
# |          MaxLogPi |             707 |
# |          MinLogPi |             119 |
# |            LossPi |           -0.66 |
# |             LossQ |            20.8 |
# |              Time |             842 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |           0.965 |
# |          StdEpRet |            3.48 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.96 |
# |      StdTestEpRet |            2.67 |
# |      MaxTestEpRet |            6.09 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |           1e+05 |
# |     AverageQ1Vals |           0.969 |
# |         StdQ1Vals |            1.23 |
# |         MaxQ1Vals |            11.5 |
# |         MinQ1Vals |           -8.53 |
# |     AverageQ2Vals |           0.969 |
# |         StdQ2Vals |            1.18 |
# |         MaxQ2Vals |            12.8 |
# |         MinQ2Vals |           -9.04 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.5 |
# |          MaxLogPi |             710 |
# |          MinLogPi |             159 |
# |            LossPi |          -0.671 |
# |             LossQ |            20.8 |
# |              Time |             879 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           0.982 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.11 |
# |      StdTestEpRet |            3.51 |
# |      MaxTestEpRet |            6.11 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.04e+05 |
# |     AverageQ1Vals |           0.955 |
# |         StdQ1Vals |            1.22 |
# |         MaxQ1Vals |            10.9 |
# |         MinQ1Vals |           -8.16 |
# |     AverageQ2Vals |           0.955 |
# |         StdQ2Vals |            1.17 |
# |         MaxQ2Vals |            11.6 |
# |         MinQ2Vals |           -8.98 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.6 |
# |          MaxLogPi |             705 |
# |          MinLogPi |             169 |
# |            LossPi |          -0.655 |
# |             LossQ |            20.8 |
# |              Time |             913 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |           0.789 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.56 |
# |      StdTestEpRet |             3.7 |
# |      MaxTestEpRet |            7.36 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.08e+05 |
# |     AverageQ1Vals |           0.955 |
# |         StdQ1Vals |            1.21 |
# |         MaxQ1Vals |            11.4 |
# |         MinQ1Vals |            -8.9 |
# |     AverageQ2Vals |           0.954 |
# |         StdQ2Vals |            1.16 |
# |         MaxQ2Vals |            11.5 |
# |         MinQ2Vals |           -8.86 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.5 |
# |          MaxLogPi |             696 |
# |          MinLogPi |             174 |
# |            LossPi |          -0.659 |
# |             LossQ |            20.9 |
# |              Time |             949 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           0.919 |
# |          StdEpRet |            3.42 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |          -0.468 |
# |      StdTestEpRet |            3.77 |
# |      MaxTestEpRet |            5.36 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.12e+05 |
# |     AverageQ1Vals |           0.959 |
# |         StdQ1Vals |             1.2 |
# |         MaxQ1Vals |            11.6 |
# |         MinQ1Vals |           -8.66 |
# |     AverageQ2Vals |            0.96 |
# |         StdQ2Vals |            1.15 |
# |         MaxQ2Vals |            11.8 |
# |         MinQ2Vals |           -8.04 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.5 |
# |          MaxLogPi |             698 |
# |          MinLogPi |             174 |
# |            LossPi |          -0.664 |
# |             LossQ |            20.9 |
# |              Time |             984 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           0.983 |
# |          StdEpRet |            3.46 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.73 |
# |      StdTestEpRet |            3.45 |
# |      MaxTestEpRet |               7 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.16e+05 |
# |     AverageQ1Vals |           0.963 |
# |         StdQ1Vals |             1.2 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -7.94 |
# |     AverageQ2Vals |           0.963 |
# |         StdQ2Vals |            1.15 |
# |         MaxQ2Vals |            11.9 |
# |         MinQ2Vals |           -8.39 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.7 |
# |          MaxLogPi |             714 |
# |          MinLogPi |             168 |
# |            LossPi |          -0.666 |
# |             LossQ |            20.9 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           0.832 |
# |          StdEpRet |            3.47 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |           0.494 |
# |      StdTestEpRet |            3.25 |
# |      MaxTestEpRet |            5.36 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |         1.2e+05 |
# |     AverageQ1Vals |           0.948 |
# |         StdQ1Vals |            1.21 |
# |         MaxQ1Vals |            11.1 |
# |         MinQ1Vals |           -7.98 |
# |     AverageQ2Vals |           0.948 |
# |         StdQ2Vals |            1.15 |
# |         MaxQ2Vals |            11.5 |
# |         MinQ2Vals |           -8.77 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.5 |
# |          MaxLogPi |             702 |
# |          MinLogPi |             181 |
# |            LossPi |          -0.658 |
# |             LossQ |            20.9 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |           0.863 |
# |          StdEpRet |            3.51 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.38 |
# |      StdTestEpRet |            3.35 |
# |      MaxTestEpRet |            7.23 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.24e+05 |
# |     AverageQ1Vals |           0.945 |
# |         StdQ1Vals |            1.19 |
# |         MaxQ1Vals |            12.2 |
# |         MinQ1Vals |           -8.08 |
# |     AverageQ2Vals |           0.946 |
# |         StdQ2Vals |            1.15 |
# |         MaxQ2Vals |              11 |
# |         MinQ2Vals |           -8.42 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.5 |
# |          MaxLogPi |             706 |
# |          MinLogPi |             152 |
# |            LossPi |          -0.655 |
# |             LossQ |              21 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           0.919 |
# |          StdEpRet |            3.43 |
# |          MaxEpRet |            7.39 |
# |          MinEpRet |              -4 |
# |  AverageTestEpRet |            1.62 |
# |      StdTestEpRet |            2.38 |
# |      MaxTestEpRet |            4.61 |
# |      MinTestEpRet |              -4 |
# |             EpLen |               1 |
# |         TestEpLen |               1 |
# | TotalEnvInteracts |        1.28e+05 |
# |     AverageQ1Vals |           0.953 |
# |         StdQ1Vals |             1.2 |
# |         MaxQ1Vals |            11.2 |
# |         MinQ1Vals |           -9.43 |
# |     AverageQ2Vals |           0.953 |
# |         StdQ2Vals |            1.15 |
# |         MaxQ2Vals |            12.1 |
# |         MinQ2Vals |           -8.24 |
# |      AverageLogPi |             445 |
# |          StdLogPi |            70.4 |
# |          MaxLogPi |             708 |
# |          MinLogPi |             165 |
# |            LossPi |          -0.664 |
# |             LossQ |              21 |
# |              Time |         5.8e+03 |
# ---------------------------------------

# %%
torch.save(ddpg_net, 'ddpg_net.pt')

# %%
td3
# Out:
# <function spinup.algos.pytorch.td3.td3.td3(env_fn, actor_critic=<class 'spinup.algos.pytorch.td3.core.MLPActorCritic'>, ac_kwargs={}, seed=0, steps_per_epoch=4000, epochs=100, replay_size=1000000, gamma=0.99, polyak=0.995, pi_lr=0.001, q_lr=0.001, batch_size=100, start_steps=10000, update_after=1000, update_every=50, act_noise=0.1, target_noise=0.2, noise_clip=0.5, policy_delay=2, num_test_episodes=10, max_ep_len=1000, logger_kwargs={}, save_freq=1)>
